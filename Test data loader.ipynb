# %%
##Test data loader guided diffusion

from guided_diffusion.image_datasets import load_data
from matplotlib import pyplot as plt
import numpy as np

# %%
data_dir= None
images_id_file='/gpfs01/berens/data/data/eyepacs/data_processed/metadata/metadata_image_circular_crop.csv'
data = load_data(data_dir=data_dir,
                 images_id_file=images_id_file,
                 batch_size=8,
                 image_size=256,
                 )

# %%
batch_0 = next(data)
# Out:
# Logging to /tmp/openai-2022-08-11-11-17-02-695343
# Number of images: 92745
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (16,40,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
len(batch_0)
# Out:
# 2

# %%
print(batch_0[0].shape)
# Out:
# torch.Size([8, 3, 256, 256])

# %%
print(batch_0[1])
# Out:
# {'y': tensor([1, 0, 1, 0, 1, 0, 1, 0])}

# %%
for i in range(1, 9):
    plt.subplot(2,4,i)
    img = batch_0[0][i-1].numpy()
    label = batch_0[1]['y'][i-1]
    print(label)
    img = (img + 1) * 127.5
    img = img.astype(np.uint8)
    plt.imshow(img.transpose(1,2,0))
    plt.axis('off')
# Out:
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
